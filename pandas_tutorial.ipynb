# %% [markdown]
# # Import data
# we will learn how to read data. This data is included in the repo that I copied from GitHub under ./warmup_data and ./data
#
# The read functions also have a correspoonding to functions when writing a data set

# %%
import pandas as pd

coffee = pd.read_csv("./warmup-data/coffee.csv")
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
results = pd.read_parquet('./data/results.parquet')
bios = pd.read_csv("./data/bios.csv")

results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %% [markdown]
# # Accessing data
# Here we look into some functions that we can use to look at the data

# %%
coffee.head(10)
coffee.tail()
coffee.sample(5, random_state=1)
# Out:
#          Day Coffee Type  Units Sold
# 3    Tuesday       Latte          20
# 7   Thursday       Latte          30
# 6   Thursday    Espresso          40
# 2    Tuesday    Espresso          30
# 10  Saturday    Espresso          45

# %%
# We can also filter rows using iloc (i = index) and loc (can use boolean expressions (e.g. logical expressions) and column names)
coffee.loc[[0,1,2]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
coffee.loc[5:8, ["Day", "Units Sold"]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30
# 8     Friday          45

# %%
# By default DataFrames gets indexes assinged per row. This we can change.
coffee.index = coffee.Day # another way of accessing a column

coffee.head() # We now see that the index is gone and replaces by the Day column
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
# An example of the index not being numeric anymore
coffee.loc[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # An example of the index not being numeric anymore
# ----> 2 coffee.loc[0:3]
#
# File ~/Documents/Code/Python/python_panda/python_tutorial_class/complete-pandas-tutorial/pandas_venv/lib/python3.12/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Documents/Code/Python/python_panda/python_tutorial_class/complete-pandas-tutorial/pandas_venv/lib/python3.12/site-packages/pandas/core/indexing.py:1411, in _LocIndexer._getitem_axis(self, key, axis)
#    1409 if isinstance(key, slice):
#    1410     self._validate_key(key, axis)
# -> 1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#
# File ~/Documents/Code/Python/python_panda/python_tutorial_class/complete-pandas-tutorial/pandas_venv/lib/python3.12/site-packages/pandas/core/indexing.py:1443, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1440     return obj.copy(deep=False)
#    1442 labels = obj._get_axis(axis)
# -> 1443 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1445 if isinstance(indexer, slice):
#    1446     return self.obj._slice(indexer, axis=axis)
#
# File ~/Documents/Code/Python/python_panda/python_tutorial_class/complete-pandas-tutorial/pandas_venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6662, in Index.slice_indexer(self, start, end, step)
#    6618 def slice_indexer(
#    6619     self,
#    6620     start: Hashable | None = None,
#    6621     end: Hashable | None = None,
#    6622     step: int | None = None,
#    6623 ) -> slice:
#    6624     """
#    6625     Compute the slice indexer for input labels and step.
#    6626
#    (...)
#    6660     slice(1, 3, None)
#    6661     """
# -> 6662     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6664     # return a slice
#    6665     if not is_scalar(start_slice):
#
# File ~/Documents/Code/Python/python_panda/python_tutorial_class/complete-pandas-tutorial/pandas_venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6879, in Index.slice_locs(self, start, end, step)
#    6877 start_slice = None
#    6878 if start is not None:
# -> 6879     start_slice = self.get_slice_bound(start, "left")
#    6880 if start_slice is None:
#    6881     start_slice = 0
#
# File ~/Documents/Code/Python/python_panda/python_tutorial_class/complete-pandas-tutorial/pandas_venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6794, in Index.get_slice_bound(self, label, side)
#    6790 original_label = label
#    6792 # For datetime indices label may be a string that has to be converted
#    6793 # to datetime boundary according to its resolution.
# -> 6794 label = self._maybe_cast_slice_bound(label, side)
#    6796 # we need to look up the label
#    6797 try:
#
# File ~/Documents/Code/Python/python_panda/python_tutorial_class/complete-pandas-tutorial/pandas_venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6727, in Index._maybe_cast_slice_bound(self, label, side)
#    6725 # reject them, if index does not contain label
#    6726 if (is_float(label) or is_integer(label)) and label not in self:
# -> 6727     self._raise_invalid_indexer("slice", label)
#    6729 return label
#
# File ~/Documents/Code/Python/python_panda/python_tutorial_class/complete-pandas-tutorial/pandas_venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:4301, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4299 if reraise is not lib.no_default:
#    4300     raise TypeError(msg) from reraise
# -> 4301 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on Index with these indexers [0] of type int

# %%
# However
coffee.loc["Monday"]
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          15

# %%
# Re-read the coffee data so reset the index
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
# Sometimes you need to iterate over the rows and columns

for index, row in coffee.iterrows():
    print(index)
    print(row["Units Sold"])
    print("\n\n\n\n\n\n")
# Out:
# 0
# 25
#
#
#
#
#
#
#
# 1
# 15
#
#
#
#
#
#
#
# 2
# 30
#
#
#
#
#
#
#
# 3
# 20
#
#
#
#
#
#
#
# 4
# 35
#
#
#
#
#
#
#
# 5
# 25
#
#
#
#
#
#
#
# 6
# 40
#
#
#
#
#
#
#
# 7
# 30
#
#
#
#
#
#
#
# 8
# 45
#
#
#
#
#
#
#
# 9
# 35
#
#
#
#
#
#
#
# 10
# 45
#
#
#
#
#
#
#
# 11
# 35
#
#
#
#
#
#
#
# 12
# 45
#
#
#
#
#
#
#
# 13
# 35

# %% [markdown]
# # Filtering Data

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# Show how to get people taller than 210 cm using the query function
bios.query("height_cm > 210")

# using the loc function
print(bios["height_cm"] > 210) # create a boolean vector 
bios.loc[bios["height_cm"] > 210] # Use the boolean vector to filter out the rows in the DataFrame
bios[bios["height_cm"] > 210] # this does the same though
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145495    False
# 145496    False
# 145497    False
# 145498    False
# 145499    False
# Name: height_cm, Length: 145500, dtype: bool
#         athlete_id                   name   born_date        born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19  Moskva (Moscow)
# 5572          5595        Santiago Aldama  1968-12-07             Quel
# 5583          5606   Paulinho Villas Boas  1963-01-26        São Paulo
# 5599          5622      Vladimir Andreyev  1945-06-14        Astrakhan
# 5609          5632        Franjo Arapović  1965-06-02              NaN
# ...            ...                    ...         ...              ...
# 140298      143804       Aaron Geramipoor  1992-09-11        Stockport
# 141018      144554          Yuta Watanabe  1994-10-13  Ayauta district
# 142044      145640          Jahlil Okafor  1995-12-15       Fort Smith
# 142930      146560             Mike Tobey  1994-10-10           Monroe
# 143712      147367           JaVale McGee  1988-01-19            Flint
#
#        born_region born_country                       NOC  height_cm  \
# 5089        Moskva          RUS              Soviet Union      220.0
# 5572      La Rioja          ESP                     Spain      213.0
# 5583     São Paulo          BRA                    Brazil      217.0
# 5599     Astrakhan          RUS              Soviet Union      215.0
# 5609           NaN          NaN        Croatia Yugoslavia      211.0
# ...            ...          ...                       ...        ...
# 140298     England          GBR  Islamic Republic of Iran      214.0
# 141018      Kagawa          JPN                     Japan      215.0
# 142044    Arkansas          USA                   Nigeria      211.0
# 142930    New York          USA                  Slovenia      213.0
# 143712    Michigan          USA             United States      213.0
#
#         weight_kg   died_date
# 5089        112.0  1993-07-24
# 5572         98.0         NaN
# 5583        106.0         NaN
# 5599         90.0         NaN
# 5609        120.0         NaN
# ...           ...         ...
# 140298        NaN         NaN
# 141018       97.0         NaN
# 142044        NaN         NaN
# 142930        NaN         NaN
# 143712        NaN         NaN
#
# [150 rows x 10 columns]

# %%
# We can also grab specific columns using the loc function
bios.loc[bios["height_cm"] > 210, ["name", "height_cm", "born_country"]]
bios[bios["height_cm"] > 210][["name", "height_cm", "born_country"]]
# Out:
#                          name  height_cm born_country
# 5089       Viktor Pankrashkin      220.0          RUS
# 5572          Santiago Aldama      213.0          ESP
# 5583     Paulinho Villas Boas      217.0          BRA
# 5599        Vladimir Andreyev      215.0          RUS
# 5609          Franjo Arapović      211.0          NaN
# ...                       ...        ...          ...
# 140298       Aaron Geramipoor      214.0          GBR
# 141018          Yuta Watanabe      215.0          JPN
# 142044          Jahlil Okafor      211.0          USA
# 142930             Mike Tobey      213.0          USA
# 143712           JaVale McGee      213.0          USA
#
# [150 rows x 3 columns]

# %%
# We can also add multiple conditions to filter by using () and &
bios[(bios["height_cm"] > 210) & (bios["born_country"] == "SWE")]
# Out:
#       athlete_id            name   born_date  born_city born_region  \
# 6070        6096  Sten Feldreich  1955-07-24  Stockholm   Stockholm
#
#      born_country     NOC  height_cm  weight_kg died_date
# 6070          SWE  Sweden      211.0       96.0       NaN

# %%
# Can do some more advanced string filtering
bios[bios["name"].str.contains("Keith")]

# Can also decide case sensitivity
bios[bios["name"].str.contains("keith|patrick", case=False)] # you can use normal regex expressions
# Out:
#         athlete_id               name   born_date              born_city  \
# 6                7      Patrick Chila  1969-11-27            Ris-Orangis
# 119            120   Patrick Wheatley  1899-01-20                Vryheid
# 319            320  Patrick De Koning  1961-04-23            Dendermonde
# 1897          1907       Keith Hanlon  1966-09-01                    NaN
# 2115          2125       Patrick Jopp  1962-01-08                    NaN
# ...            ...                ...         ...                    ...
# 143975      147633  Patrick Chinyemba  2001-01-03                    NaN
# 144172      147850      Patrick Jakob  1996-10-17  Sankt Johann in Tirol
# 144547      148239  Patrick Galbraith  1986-03-11              Haderslev
# 144565      148257    Patrick Russell  1993-01-04               Gentofte
# 145435      149158  Patrick Gasienica  1998-11-28                McHenry
#
#             born_region born_country            NOC  height_cm  weight_kg  \
# 6               Essonne          FRA         France      180.0       73.0
# 119       KwaZulu-Natal          RSA  Great Britain        NaN        NaN
# 319     Oost-Vlaanderen          BEL        Belgium      178.0       92.0
# 1897                NaN          NaN        Ireland        NaN        NaN
# 2115                NaN          NaN    Switzerland      176.0       67.0
# ...                 ...          ...            ...        ...        ...
# 143975              NaN          NaN         Zambia        NaN        NaN
# 144172            Tirol          AUT        Austria        NaN        NaN
# 144547       Syddanmark          DEN        Denmark        NaN        NaN
# 144565      Hovedstaden          DEN        Denmark      186.0       93.0
# 145435         Illinois          USA  United States        NaN        NaN
#
#          died_date
# 6              NaN
# 119     1967-11-05
# 319            NaN
# 1897           NaN
# 2115           NaN
# ...            ...
# 143975         NaN
# 144172         NaN
# 144547         NaN
# 144565         NaN
# 145435  2023-06-12
#
# [303 rows x 10 columns]
